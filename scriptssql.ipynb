-- %% [markdown]
-- # [EstudiantesDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [EstudiantesDB]    Script Date: 03/06/2026 19:06:04 ******/
CREATE DATABASE [EstudiantesDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'EstudiantesDB', FILENAME = N'C:\SQLDATA\MSSQL17.SQLEXPRESS\MSSQL\DATA\EstudiantesDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'EstudiantesDB_log', FILENAME = N'C:\SQLDATA\MSSQL17.SQLEXPRESS\MSSQL\DATA\EstudiantesDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [EstudiantesDB] SET COMPATIBILITY_LEVEL = 170
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [EstudiantesDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [EstudiantesDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [EstudiantesDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [EstudiantesDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [EstudiantesDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [EstudiantesDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [EstudiantesDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [EstudiantesDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [EstudiantesDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [EstudiantesDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [EstudiantesDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [EstudiantesDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [EstudiantesDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [EstudiantesDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [EstudiantesDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [EstudiantesDB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [EstudiantesDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [EstudiantesDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [EstudiantesDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [EstudiantesDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [EstudiantesDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [EstudiantesDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [EstudiantesDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [EstudiantesDB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [EstudiantesDB] SET  MULTI_USER 
GO
ALTER DATABASE [EstudiantesDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [EstudiantesDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [EstudiantesDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [EstudiantesDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [EstudiantesDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [EstudiantesDB] SET OPTIMIZED_LOCKING = OFF 
GO
ALTER DATABASE [EstudiantesDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [EstudiantesDB] SET QUERY_STORE = ON
GO
ALTER DATABASE [EstudiantesDB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Auditoria]

-- %%
USE [EstudiantesDB]
GO

-- %%
/****** Object:  Table [dbo].[Auditoria]    Script Date: 03/06/2026 19:06:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Auditoria](
	[IdAuditoria] [int] IDENTITY(1,1) NOT NULL,
	[Evento] [varchar](200) NULL,
	[Fecha] [datetime] NULL,
	[UsuarioSistema] [varchar](100) NULL,
	[Resultado] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[IdAuditoria] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cursos]

-- %%
/****** Object:  Table [dbo].[Cursos]    Script Date: 03/06/2026 19:06:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cursos](
	[IdCurso] [int] IDENTITY(1,1) NOT NULL,
	[NombreCurso] [varchar](100) NOT NULL,
	[Descripcion] [varchar](250) NULL,
	[IdDocente] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[IdCurso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Docentes]

-- %%
/****** Object:  Table [dbo].[Docentes]    Script Date: 03/06/2026 19:06:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Docentes](
	[IdDocente] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [varchar](100) NULL,
	[Correo] [varchar](100) NULL,
	[IdUsuario] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[IdDocente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Entregas]

-- %%
/****** Object:  Table [dbo].[Entregas]    Script Date: 03/06/2026 19:06:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Entregas](
	[IdEntrega] [int] IDENTITY(1,1) NOT NULL,
	[IdTarea] [int] NULL,
	[IdEstudiante] [int] NULL,
	[NombreArchivo] [varchar](255) NULL,
	[RutaArchivo] [varchar](500) NULL,
	[FechaEntrega] [datetime] NULL,
	[Estado] [varchar](50) NULL,
	[Nota] [decimal](5, 2) NULL,
PRIMARY KEY CLUSTERED 
(
	[IdEntrega] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Errores]

-- %%
/****** Object:  Table [dbo].[Errores]    Script Date: 03/06/2026 19:06:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Errores](
	[IdError] [int] IDENTITY(1,1) NOT NULL,
	[Descripcion] [varchar](max) NULL,
	[Fecha] [datetime] NULL,
	[WorkflowOrigen] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[IdError] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Estudiantes]

-- %%
/****** Object:  Table [dbo].[Estudiantes]    Script Date: 03/06/2026 19:06:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Estudiantes](
	[IdEstudiante] [int] IDENTITY(1,1) NOT NULL,
	[Carnet] [varchar](20) NOT NULL,
	[Nombre] [varchar](100) NOT NULL,
	[Correo] [varchar](100) NOT NULL,
	[IdUsuario] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[IdEstudiante] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Carnet] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tareas]

-- %%
/****** Object:  Table [dbo].[Tareas]    Script Date: 03/06/2026 19:06:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tareas](
	[IdTarea] [int] IDENTITY(1,1) NOT NULL,
	[Titulo] [varchar](100) NULL,
	[Descripcion] [varchar](500) NULL,
	[FechaPublicacion] [datetime] NULL,
	[FechaLimite] [datetime] NULL,
	[IdCurso] [int] NULL,
	[Estado] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[IdTarea] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
/****** Object:  Table [dbo].[Usuarios]    Script Date: 03/06/2026 19:06:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[IdUsuario] [int] IDENTITY(1,1) NOT NULL,
	[Usuario] [varchar](50) NOT NULL,
	[PasswordHash] [varchar](255) NOT NULL,
	[Rol] [varchar](20) NOT NULL,
	[Estado] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[IdUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Auditoria__Fecha__628FA481]

-- %%
ALTER TABLE [dbo].[Auditoria] ADD  DEFAULT (getdate()) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF__Errores__Fecha__656C112C]

-- %%
ALTER TABLE [dbo].[Errores] ADD  DEFAULT (getdate()) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF__Usuarios__Estado__4AB81AF0]

-- %%
ALTER TABLE [dbo].[Usuarios] ADD  DEFAULT ((1)) FOR [Estado]
GO

-- %% [markdown]
-- # [FK_Curso_Docente]

-- %%
ALTER TABLE [dbo].[Cursos]  WITH CHECK ADD  CONSTRAINT [FK_Curso_Docente] FOREIGN KEY([IdDocente])
REFERENCES [dbo].[Docentes] ([IdDocente])
GO
ALTER TABLE [dbo].[Cursos] CHECK CONSTRAINT [FK_Curso_Docente]
GO

-- %% [markdown]
-- # [FK_Docente_Usuario]

-- %%
ALTER TABLE [dbo].[Docentes]  WITH CHECK ADD  CONSTRAINT [FK_Docente_Usuario] FOREIGN KEY([IdUsuario])
REFERENCES [dbo].[Usuarios] ([IdUsuario])
GO
ALTER TABLE [dbo].[Docentes] CHECK CONSTRAINT [FK_Docente_Usuario]
GO

-- %% [markdown]
-- # [FK_Entrega_Estudiante]

-- %%
ALTER TABLE [dbo].[Entregas]  WITH CHECK ADD  CONSTRAINT [FK_Entrega_Estudiante] FOREIGN KEY([IdEstudiante])
REFERENCES [dbo].[Estudiantes] ([IdEstudiante])
GO
ALTER TABLE [dbo].[Entregas] CHECK CONSTRAINT [FK_Entrega_Estudiante]
GO

-- %% [markdown]
-- # [FK_Entrega_Tarea]

-- %%
ALTER TABLE [dbo].[Entregas]  WITH CHECK ADD  CONSTRAINT [FK_Entrega_Tarea] FOREIGN KEY([IdTarea])
REFERENCES [dbo].[Tareas] ([IdTarea])
GO
ALTER TABLE [dbo].[Entregas] CHECK CONSTRAINT [FK_Entrega_Tarea]
GO

-- %% [markdown]
-- # [FK_Estudiante_Usuario]

-- %%
ALTER TABLE [dbo].[Estudiantes]  WITH CHECK ADD  CONSTRAINT [FK_Estudiante_Usuario] FOREIGN KEY([IdUsuario])
REFERENCES [dbo].[Usuarios] ([IdUsuario])
GO
ALTER TABLE [dbo].[Estudiantes] CHECK CONSTRAINT [FK_Estudiante_Usuario]
GO

-- %% [markdown]
-- # [FK_Tarea_Curso]

-- %%
ALTER TABLE [dbo].[Tareas]  WITH CHECK ADD  CONSTRAINT [FK_Tarea_Curso] FOREIGN KEY([IdCurso])
REFERENCES [dbo].[Cursos] ([IdCurso])
GO
ALTER TABLE [dbo].[Tareas] CHECK CONSTRAINT [FK_Tarea_Curso]
GO

-- %% [markdown]
-- # [EstudiantesDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [EstudiantesDB] SET  READ_WRITE 
GO
